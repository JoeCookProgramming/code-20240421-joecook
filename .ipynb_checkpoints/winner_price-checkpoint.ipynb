# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from dateutil.relativedelta import relativedelta
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Dataset

# %%
df = pd.read_csv('interview_analysis_molecule_x_10mg_v1.tsv', sep='\t')

# %%
df.head(5)
# Out:
#    contract_id published_date  start_date  duration_extension outcome  \
# 0            1     2013-05-16  2013-05-24                  10     won
# 1            2     2013-04-29  2013-06-21                   0     won
# 2            3     2013-06-09  2014-08-14                   6     won
# 3            4     2013-05-04  2013-05-17                  19     won
# 4            5     2013-12-18  2013-12-17                   6     won
#
#   second_place_outcome    buyer    region      atc  duration  ...  \
# 0                  NaN  buyer_1  region_1  C07AB07        39  ...
# 1                  NaN  buyer_2  region_2  C07AB07        48  ...
# 2                 lost  buyer_3  region_3  C07AB07        12  ...
# 3                  NaN  buyer_4  region_4  C07AB07        36  ...
# 4                  NaN  buyer_5  region_5  C07AB07        36  ...
#
#   maximum_price_allowed active_ingredient pack_strength  \
# 0               0.10000        molecule_x          10mg
# 1           63442.21000        molecule_x          10mg
# 2               0.11635        molecule_x          10mg
# 3               0.03000        molecule_x          10mg
# 4               0.00010        molecule_x          10mg
#
#                       participants  participants_price  published_date_month  \
# 0                  participants_16              0.0004            2013-05-01
# 1                  participants_16               0.007            2013-04-01
# 2  participants_16|participants_23       0.014|0.07071            2013-06-01
# 3                  participants_16               0.025            2013-05-01
# 4                  participants_16               1e-05            2013-12-01
#
#             winner winner_price     second_place second_place_price
# 0  participants_16      0.00040              NaN                NaN
# 1  participants_16      0.00700              NaN                NaN
# 2  participants_16      0.01400  participants_23            0.07071
# 3  participants_16      0.02500              NaN                NaN
# 4  participants_16      0.00001              NaN                NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Date Issues

# %%
df['actual_months'] = ((df['end_date_extension'].astype('datetime64[ns]') - 
                      df['start_date'].astype('datetime64[ns]'))
                     /np.timedelta64(1, 'M')).astype(int)
df_dates = df[['contract_id','published_date','start_date','end_date_extension','duration','duration_extension','actual_months']]
df_dates['correct_duration'] = df_dates.apply(lambda x: True if x.duration + x.duration_extension == x.actual_months else False, axis=1)
df_dates['publish_before_start'] = df_dates.apply(lambda x: True if x.published_date < x.start_date else False, axis=1)

df_dates
# Out:
#     contract_id published_date  start_date end_date_extension  duration  \
# 0             1     2013-05-16  2013-05-24         2017-06-30        39
# 1             2     2013-04-29  2013-06-21         2017-06-30        48
# 2             3     2013-06-09  2014-08-14         2016-02-14        12
# 3             4     2013-05-04  2013-05-17         2017-12-31        36
# 4             5     2013-12-18  2013-12-17         2017-06-30        36
# 5             6     2013-12-06  2014-02-21         2019-04-20        48
# 6             7     2014-02-24  2014-01-01         2015-03-31        12
# 7             8     2014-03-08  2014-05-22         2018-03-22        36
# 8             9     2014-03-18  2014-05-30         2016-11-29        24
# 9            10     2014-09-07  2014-08-31         2020-03-31        36
# 10           11     2014-08-05  2014-10-30         2018-10-31        36
# 11           12     2015-02-17  2015-01-01         2016-03-31        12
# 12           13     2016-04-13  2016-06-25         2019-12-24        36
# 13           14     2017-10-20  2017-09-20         2021-12-19        48
# 14           15     2017-12-01  2018-01-22         2022-01-21        36
# 15           16     2017-12-29  2018-03-30         2024-05-30        48
# 16           17     2018-05-31  2018-04-01         2020-05-31        24
# 17           18     2019-05-26  2019-07-02         2023-01-01        36
# 18           19     2020-01-01  2020-08-04         2023-08-03        36
# 19           20     2019-12-19  2020-08-04         2023-08-03        36
# 20           21     2020-03-21  2020-06-20         2024-06-19        36
# 21           22     2020-06-10  2020-04-29         2022-09-30        24
# 22           23     2020-06-20  2020-07-22         2023-07-21        36
# 23           24     2020-10-11  2020-11-25         2024-12-25        49
# 24           25     2021-06-09  2021-05-20         2025-05-19        48
# 25           26     2021-07-09  2021-07-05         2026-01-05        48
# 26           27     2022-03-19  2022-03-31         2024-09-30        24
# 27           28     2022-07-02  2022-08-04         2024-08-03        12
# 28           29     2022-07-01  2022-06-17         2026-06-16        24
# 29           30     2023-07-09  2023-08-01         2025-07-31        24
# 30           31     2023-10-24  2023-09-26         2027-03-30        36
#
#     duration_extension  actual_months  correct_duration  publish_before_start
# 0                   10             49              True                  True
# 1                    0             48              True                  True
# 2                    6             18              True                  True
# 3                   19             55              True                  True
# 4                    6             42              True                 False
# 5                   14             61             False                  True
# 6                    3             14             False                 False
# 7                   10             45             False                  True
# 8                    6             30              True                  True
# 9                    7             66             False                 False
# 10                   0             48             False                  True
# 11                   3             14             False                 False
# 12                   6             41             False                  True
# 13                   3             50             False                 False
# 14                  12             47             False                  True
# 15                  26             74              True                  True
# 16                   2             25             False                 False
# 17                   6             42              True                  True
# 18                   0             35             False                  True
# 19                   0             35             False                  True
# 20                  12             47             False                  True
# 21                   6             29             False                 False
# 22                   0             35             False                  True
# 23                   0             48             False                  True
# 24                   0             47             False                 False
# 25                   6             54              True                 False
# 26                   6             30              True                  True
# 27                  12             23             False                  True
# 28                  24             47             False                 False
# 29                   0             23             False                  True
# 30                   6             42              True                 False

# %% [markdown]
# ## Show Outliers

# %%
fig, ax = plt.subplots(2,3,figsize=(16,10))

sns.distplot(df['quantity_annual'], ax=ax[0,0])
ax[0,0].set_title('Quantity Annual Distribution')
ax[0,0].set(xlim=(0, df['quantity_annual'].max()*1.1))
ax[0,0].tick_params(axis='x', rotation=45)
sns.distplot(df['quantity_total'], ax=ax[0,1])
ax[0,1].set_title('Quantity Total Distribution')
ax[0,1].set(xlim=(0, df['quantity_total'].max()*1.1))
sns.distplot(df['maximum_price_allowed'], ax=ax[0,2])
ax[0,2].set_title('Maximum Price Allowed Distribution')
ax[0,2].set(xlim=(0, df['maximum_price_allowed'].max()*1.1))

sns.boxplot(df['quantity_annual'], ax=ax[1,0])
ax[1,0].set_title('Quantity Annual Box Plot')
ax[1,0].set(xlim=(0, df['quantity_annual'].max()*1.1))
ax[1,0].tick_params(axis='x', rotation=45)
sns.boxplot(df['quantity_total'], ax=ax[1,1])
ax[1,1].set_title('Quantity Total Box Plot')
ax[1,1].set(xlim=(0, df['quantity_total'].max()*1.1))
sns.boxplot(df['maximum_price_allowed'], ax=ax[1,2])
ax[1,2].set_title('Maximum Price Allowed Box Plot')
# ax[1,2].set(xlim=(-1, df['maximum_price_allowed'].max()*1.1))

fig.tight_layout()
fig.show()

# %% [markdown]
# ## Automatically Remove Outliers

# %% [markdown]
# ### Z Score has issues due to how extreme some values are, its not detecting some anomalies

# %%
df_z = df[["contract_id","maximum_price_allowed"]]

# %%
df_z["maximum_price_allowed_z_value"] = (
        df_z["maximum_price_allowed"] - df_z["maximum_price_allowed"].mean()
    )/df_z["maximum_price_allowed"].std(ddof=0)

# %%
df_z[["contract_id","maximum_price_allowed","maximum_price_allowed_z_value"]].sort_values(by=['maximum_price_allowed_z_value'], ascending=False).head(10)
# Out:
#     contract_id  maximum_price_allowed  maximum_price_allowed_z_value
# 23           24           963542.28000                       4.470488
# 10           11           664493.87000                       2.999377
# 1             2            63442.21000                       0.042620
# 13           14             6647.87200                      -0.236768
# 2             3                0.11635                      -0.269471
# 14           15                0.10900                      -0.269471
# 0             1                0.10000                      -0.269471
# 30           31                0.09322                      -0.269471
# 7             8                0.08000                      -0.269471
# 19           20                0.07971                      -0.269471

# %% [markdown]
# ### Interquartile Range

# %%
def get_iqr(x):
    q3,q1 = np.percentile(x, [75, 25])
    iqr = q3 - q1
    return q1, q3, iqr

# %%
max_price_q1, max_price_q3, max_price_iqr = df[['maximum_price_allowed']].apply(get_iqr)[0]
quantity_annual_q1, quantity_annual_q3, quantity_annual_iqr = df[['quantity_annual']].apply(get_iqr)[0]
quantity_total_q1, quantity_total_q3, quantity_total_iqr = df[['quantity_total']].apply(get_iqr)[0]

# %%
df_quantity_annual_iqr = df[['contract_id','quantity_annual']].sort_values(by=['quantity_annual'], ascending=False)
df_quantity_annual_iqr['lower_bound'] = quantity_annual_q1 - quantity_annual_iqr*3
df_quantity_annual_iqr['upper_bound'] = quantity_annual_q3 + quantity_annual_iqr*3
df_quantity_annual_iqr['outlier'] = df_quantity_annual_iqr.apply(lambda x: True if x.quantity_annual > x.upper_bound or x.quantity_annual < x.lower_bound else False, axis=1)
df_quantity_annual_iqr.head(10)
# Out:
#     contract_id  quantity_annual  lower_bound  upper_bound  outlier
# 10           11           339387     -68321.0      98429.5     True
# 23           24           288795     -68321.0      98429.5     True
# 13           14            75544     -68321.0      98429.5    False
# 1             2            54988     -68321.0      98429.5    False
# 25           26            40014     -68321.0      98429.5    False
# 30           31            36360     -68321.0      98429.5    False
# 16           17            32875     -68321.0      98429.5    False
# 26           27            28180     -68321.0      98429.5    False
# 21           22            25750     -68321.0      98429.5    False
# 24           25            23688     -68321.0      98429.5    False

# %%
df_quantity_total_iqr = df[['contract_id','quantity_total']].sort_values(by=['quantity_total'], ascending=False)
df_quantity_total_iqr['lower_bound'] = quantity_total_q1 - quantity_total_iqr*3
df_quantity_total_iqr['upper_bound'] = quantity_total_q3 + quantity_total_iqr*3
df_quantity_total_iqr['outlier'] = df_quantity_total_iqr.apply(lambda x: True if x.quantity_total > x.upper_bound or x.quantity_total < x.lower_bound else False, axis=1)
df_quantity_total_iqr.head(10)
# Out:
#     contract_id  quantity_total    lower_bound    upper_bound  outlier
# 23           24    1.179787e+06 -162969.743791  238128.870511     True
# 10           11    1.018263e+06 -162969.743791  238128.870511     True
# 13           14    3.025601e+05 -162969.743791  238128.870511     True
# 1             2    2.202494e+05 -162969.743791  238128.870511    False
# 25           26    1.609689e+05 -162969.743791  238128.870511    False
# 30           31    1.099124e+05 -162969.743791  238128.870511    False
# 24           25    9.500735e+04 -162969.743791  238128.870511    False
# 16           17    6.652793e+04 -162969.743791  238128.870511    False
# 20           21    6.593100e+04 -162969.743791  238128.870511    False
# 17           18    6.390429e+04 -162969.743791  238128.870511    False

# %% [markdown]
# ### These are more extreme but without knowing the data I'm hesitant to remove as they could be correct.

# %%
df_max_price_iqr = df[['contract_id','maximum_price_allowed']].sort_values(by=['maximum_price_allowed'], ascending=False)
df_max_price_iqr['lower_bound'] = max_price_q1 - max_price_iqr*3
df_max_price_iqr['upper_bound'] = max_price_q3 + max_price_iqr*3
df_max_price_iqr['outlier'] = df_max_price_iqr.apply(lambda x: True if x.maximum_price_allowed > x.upper_bound or x.maximum_price_allowed < x.lower_bound else False, axis=1)
df_max_price_iqr.head(10)
# Out:
#     contract_id  maximum_price_allowed  lower_bound  upper_bound  outlier
# 23           24           963542.28000     -0.18783      0.29244     True
# 10           11           664493.87000     -0.18783      0.29244     True
# 1             2            63442.21000     -0.18783      0.29244     True
# 13           14             6647.87200     -0.18783      0.29244     True
# 2             3                0.11635     -0.18783      0.29244    False
# 14           15                0.10900     -0.18783      0.29244    False
# 0             1                0.10000     -0.18783      0.29244    False
# 30           31                0.09322     -0.18783      0.29244    False
# 7             8                0.08000     -0.18783      0.29244    False
# 19           20                0.07971     -0.18783      0.29244    False

# %% [markdown]
# ### Maximum Price Allowed seems like an important variable for predicting winner price so these anomalies will be removed. I didn't want to impute here as I know a number of factors can probably effect it that I'm currently unaware of.

# %%
df = df.drop(df_max_price_iqr[df_max_price_iqr.outlier == True].index)
df
# Out:
#     contract_id published_date  start_date  duration_extension outcome  \
# 0             1     2013-05-16  2013-05-24                  10     won
# 2             3     2013-06-09  2014-08-14                   6     won
# 3             4     2013-05-04  2013-05-17                  19     won
# 4             5     2013-12-18  2013-12-17                   6     won
# 5             6     2013-12-06  2014-02-21                  14     won
# 6             7     2014-02-24  2014-01-01                   3     won
# 7             8     2014-03-08  2014-05-22                  10     won
# 8             9     2014-03-18  2014-05-30                   6     won
# 9            10     2014-09-07  2014-08-31                   7     won
# 11           12     2015-02-17  2015-01-01                   3     won
# 12           13     2016-04-13  2016-06-25                   6     won
# 14           15     2017-12-01  2018-01-22                  12     won
# 15           16     2017-12-29  2018-03-30                  26     won
# 16           17     2018-05-31  2018-04-01                   2     won
# 17           18     2019-05-26  2019-07-02                   6     won
# 18           19     2020-01-01  2020-08-04                   0     won
# 19           20     2019-12-19  2020-08-04                   0     won
# 20           21     2020-03-21  2020-06-20                  12     won
# 21           22     2020-06-10  2020-04-29                   6     won
# 22           23     2020-06-20  2020-07-22                   0     won
# 24           25     2021-06-09  2021-05-20                   0     won
# 25           26     2021-07-09  2021-07-05                   6     won
# 26           27     2022-03-19  2022-03-31                   6     won
# 27           28     2022-07-02  2022-08-04                  12     won
# 28           29     2022-07-01  2022-06-17                  24    lost
# 29           30     2023-07-09  2023-08-01                   0     won
# 30           31     2023-10-24  2023-09-26                   6     won
#
#    second_place_outcome     buyer     region      atc  duration  ...  \
# 0                   NaN   buyer_1   region_1  C07AB07        39  ...
# 2                  lost   buyer_3   region_3  C07AB07        12  ...
# 3                   NaN   buyer_4   region_4  C07AB07        36  ...
# 4                   NaN   buyer_5   region_5  C07AB07        36  ...
# 5                   NaN   buyer_6   region_6  C07AB07        48  ...
# 6                   NaN   buyer_7   region_7  C07AB07        12  ...
# 7                  lost   buyer_8   region_8  C07AB07        36  ...
# 8                   NaN   buyer_9   region_9  C07AB07        24  ...
# 9                   NaN  buyer_10  region_10  C07AB07        36  ...
# 11                  NaN   buyer_7   region_7  C07AB07        12  ...
# 12                 lost  buyer_11  region_11  C07AB07        36  ...
# 14                  NaN  buyer_13  region_13  C07AB07        36  ...
# 15                 lost  buyer_14   region_4  C07AB07        48  ...
# 16                 lost   buyer_5   region_5  C07AB07        24  ...
# 17                 lost   buyer_3   region_3  C07AB07        36  ...
# 18                 lost  buyer_11  region_11  C07AB07        36  ...
# 19                 lost  buyer_11  region_11  C07AB07        36  ...
# 20                  NaN  buyer_15   region_9  C07AB07        36  ...
# 21                  NaN  buyer_16   region_5  C07AB07        24  ...
# 22                 lost   buyer_8   region_8  C07AB07        36  ...
# 24                  NaN  buyer_17  region_14  C07AB07        48  ...
# 25                  NaN  buyer_12  region_12  C07AB07        48  ...
# 26                  NaN  buyer_18  region_15  C07AB07        24  ...
# 27                 lost  buyer_19   region_6  C07AB07        12  ...
# 28                  won  buyer_16  region_16  C07AB07        24  ...
# 29                 lost  buyer_19   region_6  C07AB07        24  ...
# 30                 lost   buyer_8   region_8      NaN        36  ...
#
#    active_ingredient pack_strength  \
# 0         molecule_x          10mg
# 2         molecule_x          10mg
# 3         molecule_x          10mg
# 4         molecule_x          10mg
# 5         molecule_x          10mg
# 6         molecule_x          10mg
# 7         molecule_x          10mg
# 8         molecule_x          10mg
# 9         molecule_x          10mg
# 11        molecule_x          10mg
# 12        molecule_x          10mg
# 14        molecule_x          10mg
# 15        molecule_x          10mg
# 16        molecule_x          10mg
# 17        molecule_x          10mg
# 18        molecule_x          10mg
# 19        molecule_x          10mg
# 20        molecule_x          10mg
# 21        molecule_x          10mg
# 22        molecule_x          10mg
# 24        molecule_x          10mg
# 25        molecule_x          10mg
# 26        molecule_x          10mg
# 27        molecule_x          10mg
# 28        molecule_x          10mg
# 29        molecule_x          10mg
# 30        molecule_x          10mg
#
#                                          participants  \
# 0                                     participants_16
# 2                     participants_16|participants_23
# 3                                     participants_16
# 4                                     participants_16
# 5                                     participants_16
# 6                                     participants_16
# 7   participants_16|participants_5|participants_6|...
# 8                                     participants_16
# 9                                     participants_16
# 11                                    participants_16
# 12  participants_6|participants_16|participants_23...
# 14                                    participants_16
# 15                     participants_16|participants_4
# 16                     participants_16|participants_7
# 17                    participants_16|participants_19
# 18    participants_19|participants_16|participants_23
# 19    participants_19|participants_16|participants_23
# 20                                    participants_19
# 21                                    participants_19
# 22     participants_19|participants_8|participants_23
# 24                                    participants_19
# 25                                    participants_19
# 26                                    participants_19
# 27                    participants_19|participants_23
# 28                    participants_19|participants_23
# 29    participants_19|participants_16|participants_23
# 30  participants_19|participants_7|participants_16...
#
#              participants_price  published_date_month           winner  \
# 0                        0.0004            2013-05-01  participants_16
# 2                 0.014|0.07071            2013-06-01  participants_16
# 3                         0.025            2013-05-01  participants_16
# 4                         1e-05            2013-12-01  participants_16
# 5                         0.019            2013-12-01  participants_16
# 6                         1e-05            2014-02-01  participants_16
# 7       0.03|0.08|0.034|0.04066            2014-03-01  participants_16
# 8                         1e-05            2014-03-01  participants_16
# 9                        0.0001            2014-09-01  participants_16
# 11                        5e-05            2015-02-01  participants_16
# 12   0.01699|0.07|0.06802|0.075            2016-04-01   participants_6
# 14                         0.05            2017-12-01  participants_16
# 15                 0.017|0.0242            2017-12-01  participants_16
# 16      0.02|0.9993156095718888            2018-05-01  participants_16
# 17      0.02|0.8665684755636098            2019-05-01  participants_16
# 18         0.01786|0.07|0.06511            2020-01-01  participants_19
# 19         0.01786|0.07|0.06511            2019-12-01  participants_19
# 20                      0.01607            2020-03-01  participants_19
# 21                       0.0125            2020-06-01  participants_19
# 22          0.035|0.038|0.03929            2020-06-01  participants_19
# 24                       0.0123            2021-06-01  participants_19
# 25                        0.018            2021-07-01  participants_19
# 26                       0.0122            2022-03-01  participants_19
# 27                0.015|0.01571            2022-07-01  participants_19
# 28                0.034|0.02393            2022-07-01  participants_23
# 29          0.015|0.025|0.02679            2023-07-01  participants_19
# 30  0.0155|0.06256|0.08|0.09286            2023-10-01  participants_19
#
#     winner_price     second_place second_place_price actual_months
# 0        0.00040              NaN                NaN            49
# 2        0.01400  participants_23           0.070710            18
# 3        0.02500              NaN                NaN            55
# 4        0.00001              NaN                NaN            42
# 5        0.01900              NaN                NaN            61
# 6        0.00001              NaN                NaN            14
# 7        0.03000   participants_6           0.034000            45
# 8        0.00001              NaN                NaN            30
# 9        0.00010              NaN                NaN            66
# 11       0.00005              NaN                NaN            14
# 12       0.01699  participants_23           0.068020            41
# 14       0.05000              NaN                NaN            47
# 15       0.01700   participants_4           0.024200            74
# 16       0.02000   participants_7           0.999316            25
# 17       0.02000  participants_19           0.866568            42
# 18       0.01786  participants_23           0.065110            35
# 19       0.01786  participants_23           0.065110            35
# 20       0.01607              NaN                NaN            47
# 21       0.01250              NaN                NaN            29
# 22       0.03500   participants_8           0.038000            35
# 24       0.01230              NaN                NaN            47
# 25       0.01800              NaN                NaN            54
# 26       0.01220              NaN                NaN            30
# 27       0.01500  participants_23           0.015710            23
# 28       0.02393  participants_19           0.034000            47
# 29       0.01500  participants_16           0.025000            23
# 30       0.01550   participants_7           0.062560            42
#
# [27 rows x 27 columns]

# %% [markdown]
# ## Winner Price Analysis

# %%
fig, ax = plt.subplots(1,2,figsize=(16,7))

sns.distplot(df['winner_price'], ax=ax[0])
ax[0].set_title('Winner Price Distribution')
ax[0].set(xlim=(0, df['winner_price'].max()*1.1))
ax[0].tick_params(axis='x', rotation=45)

sns.boxplot(df['winner_price'], ax=ax[1])
ax[1].set_title('Winner Price Boxplot')
ax[1].set(xlim=(0, df['winner_price'].max()*1.1))
ax[1].tick_params(axis='x', rotation=45)

fig.tight_layout()
fig.show()

# %%
plt.subplots(figsize=(16,10))

sns.lineplot(data=df, x="start_date", y="winner_price").set_title('Winner Price by Start Date')
plt.tick_params(axis='x', rotation=45)

fig.tight_layout()
fig.show()

# %% [markdown]
# ## Static Threshold Removal

# %% [markdown]
# ### I'm not familiar enough with the data to know for sure if these are outliers but I suspect they are so I'm going to remove them. Due to the small volume of data, methods like using Z-Scores or Interquartile ranges arent too effective.

# %%
winner_price_lower_bound = 0.001
winner_price_upper_bound = 0.05
df = df.drop(df[df['winner_price'] < winner_price_lower_bound].index)
df = df.drop(df[df['winner_price'] > winner_price_upper_bound].index)
df = df[df['winner_price'].notna()]
df
# Out:
#     contract_id published_date  start_date  duration_extension outcome  \
# 2             3     2013-06-09  2014-08-14                   6     won
# 3             4     2013-05-04  2013-05-17                  19     won
# 5             6     2013-12-06  2014-02-21                  14     won
# 7             8     2014-03-08  2014-05-22                  10     won
# 12           13     2016-04-13  2016-06-25                   6     won
# 14           15     2017-12-01  2018-01-22                  12     won
# 15           16     2017-12-29  2018-03-30                  26     won
# 16           17     2018-05-31  2018-04-01                   2     won
# 17           18     2019-05-26  2019-07-02                   6     won
# 18           19     2020-01-01  2020-08-04                   0     won
# 19           20     2019-12-19  2020-08-04                   0     won
# 20           21     2020-03-21  2020-06-20                  12     won
# 21           22     2020-06-10  2020-04-29                   6     won
# 22           23     2020-06-20  2020-07-22                   0     won
# 24           25     2021-06-09  2021-05-20                   0     won
# 25           26     2021-07-09  2021-07-05                   6     won
# 26           27     2022-03-19  2022-03-31                   6     won
# 27           28     2022-07-02  2022-08-04                  12     won
# 28           29     2022-07-01  2022-06-17                  24    lost
# 29           30     2023-07-09  2023-08-01                   0     won
# 30           31     2023-10-24  2023-09-26                   6     won
#
#    second_place_outcome     buyer     region      atc  duration  ...  \
# 2                  lost   buyer_3   region_3  C07AB07        12  ...
# 3                   NaN   buyer_4   region_4  C07AB07        36  ...
# 5                   NaN   buyer_6   region_6  C07AB07        48  ...
# 7                  lost   buyer_8   region_8  C07AB07        36  ...
# 12                 lost  buyer_11  region_11  C07AB07        36  ...
# 14                  NaN  buyer_13  region_13  C07AB07        36  ...
# 15                 lost  buyer_14   region_4  C07AB07        48  ...
# 16                 lost   buyer_5   region_5  C07AB07        24  ...
# 17                 lost   buyer_3   region_3  C07AB07        36  ...
# 18                 lost  buyer_11  region_11  C07AB07        36  ...
# 19                 lost  buyer_11  region_11  C07AB07        36  ...
# 20                  NaN  buyer_15   region_9  C07AB07        36  ...
# 21                  NaN  buyer_16   region_5  C07AB07        24  ...
# 22                 lost   buyer_8   region_8  C07AB07        36  ...
# 24                  NaN  buyer_17  region_14  C07AB07        48  ...
# 25                  NaN  buyer_12  region_12  C07AB07        48  ...
# 26                  NaN  buyer_18  region_15  C07AB07        24  ...
# 27                 lost  buyer_19   region_6  C07AB07        12  ...
# 28                  won  buyer_16  region_16  C07AB07        24  ...
# 29                 lost  buyer_19   region_6  C07AB07        24  ...
# 30                 lost   buyer_8   region_8      NaN        36  ...
#
#    active_ingredient pack_strength  \
# 2         molecule_x          10mg
# 3         molecule_x          10mg
# 5         molecule_x          10mg
# 7         molecule_x          10mg
# 12        molecule_x          10mg
# 14        molecule_x          10mg
# 15        molecule_x          10mg
# 16        molecule_x          10mg
# 17        molecule_x          10mg
# 18        molecule_x          10mg
# 19        molecule_x          10mg
# 20        molecule_x          10mg
# 21        molecule_x          10mg
# 22        molecule_x          10mg
# 24        molecule_x          10mg
# 25        molecule_x          10mg
# 26        molecule_x          10mg
# 27        molecule_x          10mg
# 28        molecule_x          10mg
# 29        molecule_x          10mg
# 30        molecule_x          10mg
#
#                                          participants  \
# 2                     participants_16|participants_23
# 3                                     participants_16
# 5                                     participants_16
# 7   participants_16|participants_5|participants_6|...
# 12  participants_6|participants_16|participants_23...
# 14                                    participants_16
# 15                     participants_16|participants_4
# 16                     participants_16|participants_7
# 17                    participants_16|participants_19
# 18    participants_19|participants_16|participants_23
# 19    participants_19|participants_16|participants_23
# 20                                    participants_19
# 21                                    participants_19
# 22     participants_19|participants_8|participants_23
# 24                                    participants_19
# 25                                    participants_19
# 26                                    participants_19
# 27                    participants_19|participants_23
# 28                    participants_19|participants_23
# 29    participants_19|participants_16|participants_23
# 30  participants_19|participants_7|participants_16...
#
#              participants_price  published_date_month           winner  \
# 2                 0.014|0.07071            2013-06-01  participants_16
# 3                         0.025            2013-05-01  participants_16
# 5                         0.019            2013-12-01  participants_16
# 7       0.03|0.08|0.034|0.04066            2014-03-01  participants_16
# 12   0.01699|0.07|0.06802|0.075            2016-04-01   participants_6
# 14                         0.05            2017-12-01  participants_16
# 15                 0.017|0.0242            2017-12-01  participants_16
# 16      0.02|0.9993156095718888            2018-05-01  participants_16
# 17      0.02|0.8665684755636098            2019-05-01  participants_16
# 18         0.01786|0.07|0.06511            2020-01-01  participants_19
# 19         0.01786|0.07|0.06511            2019-12-01  participants_19
# 20                      0.01607            2020-03-01  participants_19
# 21                       0.0125            2020-06-01  participants_19
# 22          0.035|0.038|0.03929            2020-06-01  participants_19
# 24                       0.0123            2021-06-01  participants_19
# 25                        0.018            2021-07-01  participants_19
# 26                       0.0122            2022-03-01  participants_19
# 27                0.015|0.01571            2022-07-01  participants_19
# 28                0.034|0.02393            2022-07-01  participants_23
# 29          0.015|0.025|0.02679            2023-07-01  participants_19
# 30  0.0155|0.06256|0.08|0.09286            2023-10-01  participants_19
#
#     winner_price     second_place second_place_price actual_months
# 2        0.01400  participants_23           0.070710            18
# 3        0.02500              NaN                NaN            55
# 5        0.01900              NaN                NaN            61
# 7        0.03000   participants_6           0.034000            45
# 12       0.01699  participants_23           0.068020            41
# 14       0.05000              NaN                NaN            47
# 15       0.01700   participants_4           0.024200            74
# 16       0.02000   participants_7           0.999316            25
# 17       0.02000  participants_19           0.866568            42
# 18       0.01786  participants_23           0.065110            35
# 19       0.01786  participants_23           0.065110            35
# 20       0.01607              NaN                NaN            47
# 21       0.01250              NaN                NaN            29
# 22       0.03500   participants_8           0.038000            35
# 24       0.01230              NaN                NaN            47
# 25       0.01800              NaN                NaN            54
# 26       0.01220              NaN                NaN            30
# 27       0.01500  participants_23           0.015710            23
# 28       0.02393  participants_19           0.034000            47
# 29       0.01500  participants_16           0.025000            23
# 30       0.01550   participants_7           0.062560            42
#
# [21 rows x 27 columns]

# %%
plt.subplots(figsize=(16,10))

sns.lineplot(data=df, x="start_date", y="winner_price").set_title('Winner Price by Start Date')
plt.tick_params(axis='x', rotation=45)

fig.tight_layout()
fig.show()

# %% [markdown]
# ## Imputing Missing Data

# %%
# dummy data to show it works with more skus
# df.loc[df['contract_id'].isin([30,31]), 'sku'] = 'TEST_SKU'
# df.loc[df['contract_id'].isin([30]), 'atc'] = 'TEST_ATC'
# df['sku']

# %%
df['atc'] = df.groupby(['sku'])['atc'].apply(lambda x: x.fillna(x.mode()[0]))
df
# Out:
#     contract_id published_date  start_date  duration_extension outcome  \
# 2             3     2013-06-09  2014-08-14                   6     won
# 3             4     2013-05-04  2013-05-17                  19     won
# 5             6     2013-12-06  2014-02-21                  14     won
# 7             8     2014-03-08  2014-05-22                  10     won
# 12           13     2016-04-13  2016-06-25                   6     won
# 14           15     2017-12-01  2018-01-22                  12     won
# 15           16     2017-12-29  2018-03-30                  26     won
# 16           17     2018-05-31  2018-04-01                   2     won
# 17           18     2019-05-26  2019-07-02                   6     won
# 18           19     2020-01-01  2020-08-04                   0     won
# 19           20     2019-12-19  2020-08-04                   0     won
# 20           21     2020-03-21  2020-06-20                  12     won
# 21           22     2020-06-10  2020-04-29                   6     won
# 22           23     2020-06-20  2020-07-22                   0     won
# 24           25     2021-06-09  2021-05-20                   0     won
# 25           26     2021-07-09  2021-07-05                   6     won
# 26           27     2022-03-19  2022-03-31                   6     won
# 27           28     2022-07-02  2022-08-04                  12     won
# 28           29     2022-07-01  2022-06-17                  24    lost
# 29           30     2023-07-09  2023-08-01                   0     won
# 30           31     2023-10-24  2023-09-26                   6     won
#
#    second_place_outcome     buyer     region      atc  duration  ...  \
# 2                  lost   buyer_3   region_3  C07AB07        12  ...
# 3                   NaN   buyer_4   region_4  C07AB07        36  ...
# 5                   NaN   buyer_6   region_6  C07AB07        48  ...
# 7                  lost   buyer_8   region_8  C07AB07        36  ...
# 12                 lost  buyer_11  region_11  C07AB07        36  ...
# 14                  NaN  buyer_13  region_13  C07AB07        36  ...
# 15                 lost  buyer_14   region_4  C07AB07        48  ...
# 16                 lost   buyer_5   region_5  C07AB07        24  ...
# 17                 lost   buyer_3   region_3  C07AB07        36  ...
# 18                 lost  buyer_11  region_11  C07AB07        36  ...
# 19                 lost  buyer_11  region_11  C07AB07        36  ...
# 20                  NaN  buyer_15   region_9  C07AB07        36  ...
# 21                  NaN  buyer_16   region_5  C07AB07        24  ...
# 22                 lost   buyer_8   region_8  C07AB07        36  ...
# 24                  NaN  buyer_17  region_14  C07AB07        48  ...
# 25                  NaN  buyer_12  region_12  C07AB07        48  ...
# 26                  NaN  buyer_18  region_15  C07AB07        24  ...
# 27                 lost  buyer_19   region_6  C07AB07        12  ...
# 28                  won  buyer_16  region_16  C07AB07        24  ...
# 29                 lost  buyer_19   region_6  C07AB07        24  ...
# 30                 lost   buyer_8   region_8  C07AB07        36  ...
#
#    active_ingredient pack_strength  \
# 2         molecule_x          10mg
# 3         molecule_x          10mg
# 5         molecule_x          10mg
# 7         molecule_x          10mg
# 12        molecule_x          10mg
# 14        molecule_x          10mg
# 15        molecule_x          10mg
# 16        molecule_x          10mg
# 17        molecule_x          10mg
# 18        molecule_x          10mg
# 19        molecule_x          10mg
# 20        molecule_x          10mg
# 21        molecule_x          10mg
# 22        molecule_x          10mg
# 24        molecule_x          10mg
# 25        molecule_x          10mg
# 26        molecule_x          10mg
# 27        molecule_x          10mg
# 28        molecule_x          10mg
# 29        molecule_x          10mg
# 30        molecule_x          10mg
#
#                                          participants  \
# 2                     participants_16|participants_23
# 3                                     participants_16
# 5                                     participants_16
# 7   participants_16|participants_5|participants_6|...
# 12  participants_6|participants_16|participants_23...
# 14                                    participants_16
# 15                     participants_16|participants_4
# 16                     participants_16|participants_7
# 17                    participants_16|participants_19
# 18    participants_19|participants_16|participants_23
# 19    participants_19|participants_16|participants_23
# 20                                    participants_19
# 21                                    participants_19
# 22     participants_19|participants_8|participants_23
# 24                                    participants_19
# 25                                    participants_19
# 26                                    participants_19
# 27                    participants_19|participants_23
# 28                    participants_19|participants_23
# 29    participants_19|participants_16|participants_23
# 30  participants_19|participants_7|participants_16...
#
#              participants_price  published_date_month           winner  \
# 2                 0.014|0.07071            2013-06-01  participants_16
# 3                         0.025            2013-05-01  participants_16
# 5                         0.019            2013-12-01  participants_16
# 7       0.03|0.08|0.034|0.04066            2014-03-01  participants_16
# 12   0.01699|0.07|0.06802|0.075            2016-04-01   participants_6
# 14                         0.05            2017-12-01  participants_16
# 15                 0.017|0.0242            2017-12-01  participants_16
# 16      0.02|0.9993156095718888            2018-05-01  participants_16
# 17      0.02|0.8665684755636098            2019-05-01  participants_16
# 18         0.01786|0.07|0.06511            2020-01-01  participants_19
# 19         0.01786|0.07|0.06511            2019-12-01  participants_19
# 20                      0.01607            2020-03-01  participants_19
# 21                       0.0125            2020-06-01  participants_19
# 22          0.035|0.038|0.03929            2020-06-01  participants_19
# 24                       0.0123            2021-06-01  participants_19
# 25                        0.018            2021-07-01  participants_19
# 26                       0.0122            2022-03-01  participants_19
# 27                0.015|0.01571            2022-07-01  participants_19
# 28                0.034|0.02393            2022-07-01  participants_23
# 29          0.015|0.025|0.02679            2023-07-01  participants_19
# 30  0.0155|0.06256|0.08|0.09286            2023-10-01  participants_19
#
#     winner_price     second_place second_place_price actual_months
# 2        0.01400  participants_23           0.070710            18
# 3        0.02500              NaN                NaN            55
# 5        0.01900              NaN                NaN            61
# 7        0.03000   participants_6           0.034000            45
# 12       0.01699  participants_23           0.068020            41
# 14       0.05000              NaN                NaN            47
# 15       0.01700   participants_4           0.024200            74
# 16       0.02000   participants_7           0.999316            25
# 17       0.02000  participants_19           0.866568            42
# 18       0.01786  participants_23           0.065110            35
# 19       0.01786  participants_23           0.065110            35
# 20       0.01607              NaN                NaN            47
# 21       0.01250              NaN                NaN            29
# 22       0.03500   participants_8           0.038000            35
# 24       0.01230              NaN                NaN            47
# 25       0.01800              NaN                NaN            54
# 26       0.01220              NaN                NaN            30
# 27       0.01500  participants_23           0.015710            23
# 28       0.02393  participants_19           0.034000            47
# 29       0.01500  participants_16           0.025000            23
# 30       0.01550   participants_7           0.062560            42
#
# [21 rows x 27 columns]

# %% [markdown]
# ## Clean Participants Price

# %%
def price_fix(x):
    return "|".join(["{:.05f}".format(float(str(i))) for i in x.split('|')])

# %%
df['participants_price'] = df['participants_price'].apply(price_fix) 
df
# Out:
#     contract_id published_date  start_date  duration_extension outcome  \
# 2             3     2013-06-09  2014-08-14                   6     won
# 3             4     2013-05-04  2013-05-17                  19     won
# 5             6     2013-12-06  2014-02-21                  14     won
# 7             8     2014-03-08  2014-05-22                  10     won
# 12           13     2016-04-13  2016-06-25                   6     won
# 14           15     2017-12-01  2018-01-22                  12     won
# 15           16     2017-12-29  2018-03-30                  26     won
# 16           17     2018-05-31  2018-04-01                   2     won
# 17           18     2019-05-26  2019-07-02                   6     won
# 18           19     2020-01-01  2020-08-04                   0     won
# 19           20     2019-12-19  2020-08-04                   0     won
# 20           21     2020-03-21  2020-06-20                  12     won
# 21           22     2020-06-10  2020-04-29                   6     won
# 22           23     2020-06-20  2020-07-22                   0     won
# 24           25     2021-06-09  2021-05-20                   0     won
# 25           26     2021-07-09  2021-07-05                   6     won
# 26           27     2022-03-19  2022-03-31                   6     won
# 27           28     2022-07-02  2022-08-04                  12     won
# 28           29     2022-07-01  2022-06-17                  24    lost
# 29           30     2023-07-09  2023-08-01                   0     won
# 30           31     2023-10-24  2023-09-26                   6     won
#
#    second_place_outcome     buyer     region      atc  duration  ...  \
# 2                  lost   buyer_3   region_3  C07AB07        12  ...
# 3                   NaN   buyer_4   region_4  C07AB07        36  ...
# 5                   NaN   buyer_6   region_6  C07AB07        48  ...
# 7                  lost   buyer_8   region_8  C07AB07        36  ...
# 12                 lost  buyer_11  region_11  C07AB07        36  ...
# 14                  NaN  buyer_13  region_13  C07AB07        36  ...
# 15                 lost  buyer_14   region_4  C07AB07        48  ...
# 16                 lost   buyer_5   region_5  C07AB07        24  ...
# 17                 lost   buyer_3   region_3  C07AB07        36  ...
# 18                 lost  buyer_11  region_11  C07AB07        36  ...
# 19                 lost  buyer_11  region_11  C07AB07        36  ...
# 20                  NaN  buyer_15   region_9  C07AB07        36  ...
# 21                  NaN  buyer_16   region_5  C07AB07        24  ...
# 22                 lost   buyer_8   region_8  C07AB07        36  ...
# 24                  NaN  buyer_17  region_14  C07AB07        48  ...
# 25                  NaN  buyer_12  region_12  C07AB07        48  ...
# 26                  NaN  buyer_18  region_15  C07AB07        24  ...
# 27                 lost  buyer_19   region_6  C07AB07        12  ...
# 28                  won  buyer_16  region_16  C07AB07        24  ...
# 29                 lost  buyer_19   region_6  C07AB07        24  ...
# 30                 lost   buyer_8   region_8  C07AB07        36  ...
#
#    active_ingredient pack_strength  \
# 2         molecule_x          10mg
# 3         molecule_x          10mg
# 5         molecule_x          10mg
# 7         molecule_x          10mg
# 12        molecule_x          10mg
# 14        molecule_x          10mg
# 15        molecule_x          10mg
# 16        molecule_x          10mg
# 17        molecule_x          10mg
# 18        molecule_x          10mg
# 19        molecule_x          10mg
# 20        molecule_x          10mg
# 21        molecule_x          10mg
# 22        molecule_x          10mg
# 24        molecule_x          10mg
# 25        molecule_x          10mg
# 26        molecule_x          10mg
# 27        molecule_x          10mg
# 28        molecule_x          10mg
# 29        molecule_x          10mg
# 30        molecule_x          10mg
#
#                                          participants  \
# 2                     participants_16|participants_23
# 3                                     participants_16
# 5                                     participants_16
# 7   participants_16|participants_5|participants_6|...
# 12  participants_6|participants_16|participants_23...
# 14                                    participants_16
# 15                     participants_16|participants_4
# 16                     participants_16|participants_7
# 17                    participants_16|participants_19
# 18    participants_19|participants_16|participants_23
# 19    participants_19|participants_16|participants_23
# 20                                    participants_19
# 21                                    participants_19
# 22     participants_19|participants_8|participants_23
# 24                                    participants_19
# 25                                    participants_19
# 26                                    participants_19
# 27                    participants_19|participants_23
# 28                    participants_19|participants_23
# 29    participants_19|participants_16|participants_23
# 30  participants_19|participants_7|participants_16...
#
#                  participants_price  published_date_month           winner  \
# 2                   0.01400|0.07071            2013-06-01  participants_16
# 3                           0.02500            2013-05-01  participants_16
# 5                           0.01900            2013-12-01  participants_16
# 7   0.03000|0.08000|0.03400|0.04066            2014-03-01  participants_16
# 12  0.01699|0.07000|0.06802|0.07500            2016-04-01   participants_6
# 14                          0.05000            2017-12-01  participants_16
# 15                  0.01700|0.02420            2017-12-01  participants_16
# 16                  0.02000|0.99932            2018-05-01  participants_16
# 17                  0.02000|0.86657            2019-05-01  participants_16
# 18          0.01786|0.07000|0.06511            2020-01-01  participants_19
# 19          0.01786|0.07000|0.06511            2019-12-01  participants_19
# 20                          0.01607            2020-03-01  participants_19
# 21                          0.01250            2020-06-01  participants_19
# 22          0.03500|0.03800|0.03929            2020-06-01  participants_19
# 24                          0.01230            2021-06-01  participants_19
# 25                          0.01800            2021-07-01  participants_19
# 26                          0.01220            2022-03-01  participants_19
# 27                  0.01500|0.01571            2022-07-01  participants_19
# 28                  0.03400|0.02393            2022-07-01  participants_23
# 29          0.01500|0.02500|0.02679            2023-07-01  participants_19
# 30  0.01550|0.06256|0.08000|0.09286            2023-10-01  participants_19
#
#     winner_price     second_place second_place_price actual_months
# 2        0.01400  participants_23           0.070710            18
# 3        0.02500              NaN                NaN            55
# 5        0.01900              NaN                NaN            61
# 7        0.03000   participants_6           0.034000            45
# 12       0.01699  participants_23           0.068020            41
# 14       0.05000              NaN                NaN            47
# 15       0.01700   participants_4           0.024200            74
# 16       0.02000   participants_7           0.999316            25
# 17       0.02000  participants_19           0.866568            42
# 18       0.01786  participants_23           0.065110            35
# 19       0.01786  participants_23           0.065110            35
# 20       0.01607              NaN                NaN            47
# 21       0.01250              NaN                NaN            29
# 22       0.03500   participants_8           0.038000            35
# 24       0.01230              NaN                NaN            47
# 25       0.01800              NaN                NaN            54
# 26       0.01220              NaN                NaN            30
# 27       0.01500  participants_23           0.015710            23
# 28       0.02393  participants_19           0.034000            47
# 29       0.01500  participants_16           0.025000            23
# 30       0.01550   participants_7           0.062560            42
#
# [21 rows x 27 columns]

# %%
df.to_csv('output.tsv', sep="\t")
